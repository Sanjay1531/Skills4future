# %% [markdown]
# # Air Quality Analysis using Python

# %% [markdown]
# #  Step-1 import libraries

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # step-2 Fetch AQI Data

# %%
api_key='e6dc0001ad15356a4bd639a628ff4045'
city = 'MYSORE'

# %%
def fetch_aqi_data(api_key,city,start,end):
    geo_url=f'http://api.openweathermap.org/geo/1.0/direct?q={city}&limit=1&appid={api_key}'
    geo_response=requests.get(geo_url)
    geo_data=geo_response.json()
    if len(geo_data)==0:
        raise ValueError(f"City{city}not found")

    lat=geo_data[0]['lat']
    lon=geo_data[0]['lon']

    url=f'http://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={api_key}'
    response=requests.get(url)
    data=response.json()
    return data

end_time=int(datetime.datetime.now().timestamp())
start_time=end_time -(7*24*60*60)
aqi_data=fetch_aqi_data(api_key,city,start_time,end_time)

# %%
aqi_data
# Out:
# {'coord': {'lon': 76.6554, 'lat': 12.3052},
#  'list': [{'main': {'aqi': 1},
#    'components': {'co': 417.23,
#     'no': 1.45,
#     'no2': 6.85,
#     'o3': 50.07,
#     'so2': 3.93,
#     'pm2_5': 4.54,
#     'pm10': 6.2,
#     'nh3': 2.15},
#    'dt': 1731477600},
#   {'main': {'aqi': 2},
#    'components': {'co': 387.19,
#     'no': 0.85,
#     'no2': 5.74,
#     'o3': 63.66,
#     'so2': 3.73,
#     'pm2_5': 5.47,
#     'pm10': 6.72,
#     'nh3': 1.76},
#    'dt': 1731481200},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.46,
#     'no2': 6.08,
#     'o3': 68.66,
#     'so2': 3.76,
#     'pm2_5': 6.81,
#     'pm10': 7.93,
#     'nh3': 1.71},
#    'dt': 1731484800},
#   {'main': {'aqi': 2},
#    'components': {'co': 373.84,
#     'no': 0.18,
#     'no2': 6.6,
#     'o3': 65.09,
#     'so2': 3.55,
#     'pm2_5': 5.64,
#     'pm10': 6.59,
#     'nh3': 1.57},
#    'dt': 1731488400},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.03,
#     'no2': 8.23,
#     'o3': 53.64,
#     'so2': 3.73,
#     'pm2_5': 4.33,
#     'pm10': 5.35,
#     'nh3': 1.76},
#    'dt': 1731492000},
#   {'main': {'aqi': 1},
#    'components': {'co': 397.21,
#     'no': 0.06,
#     'no2': 11.14,
#     'o3': 42.92,
#     'so2': 3.81,
#     'pm2_5': 4.15,
#     'pm10': 5.45,
#     'nh3': 2.09},
#    'dt': 1731495600},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 0.04,
#     'no2': 15.08,
#     'o3': 33.97,
#     'so2': 3.81,
#     'pm2_5': 4.39,
#     'pm10': 6.04,
#     'nh3': 2.22},
#    'dt': 1731499200},
#   {'main': {'aqi': 1},
#    'components': {'co': 447.27,
#     'no': 0.02,
#     'no2': 17.31,
#     'o3': 27.18,
#     'so2': 3.64,
#     'pm2_5': 4.93,
#     'pm10': 7.29,
#     'nh3': 2.44},
#    'dt': 1731502800},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.03,
#     'no2': 17.31,
#     'o3': 23.25,
#     'so2': 3.73,
#     'pm2_5': 5.58,
#     'pm10': 8.87,
#     'nh3': 2.66},
#    'dt': 1731506400},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.04,
#     'no2': 16.45,
#     'o3': 20.03,
#     'so2': 3.73,
#     'pm2_5': 6.16,
#     'pm10': 10.06,
#     'nh3': 2.66},
#    'dt': 1731510000},
#   {'main': {'aqi': 1},
#    'components': {'co': 447.27,
#     'no': 0.05,
#     'no2': 15.08,
#     'o3': 17.88,
#     'so2': 3.52,
#     'pm2_5': 6.43,
#     'pm10': 10.68,
#     'nh3': 2.6},
#    'dt': 1731513600},
#   {'main': {'aqi': 1},
#    'components': {'co': 440.6,
#     'no': 0.06,
#     'no2': 13.54,
#     'o3': 16.27,
#     'so2': 3.25,
#     'pm2_5': 6.35,
#     'pm10': 10.72,
#     'nh3': 2.6},
#    'dt': 1731517200},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 0.05,
#     'no2': 12.51,
#     'o3': 15.74,
#     'so2': 2.89,
#     'pm2_5': 5.9,
#     'pm10': 9.86,
#     'nh3': 2.5},
#    'dt': 1731520800},
#   {'main': {'aqi': 1},
#    'components': {'co': 407.22,
#     'no': 0.03,
#     'no2': 11.14,
#     'o3': 16.09,
#     'so2': 2.56,
#     'pm2_5': 5.23,
#     'pm10': 8.02,
#     'nh3': 2.28},
#    'dt': 1731524400},
#   {'main': {'aqi': 1},
#    'components': {'co': 390.53,
#     'no': 0.02,
#     'no2': 9.42,
#     'o3': 16.63,
#     'so2': 2.29,
#     'pm2_5': 4.81,
#     'pm10': 6.76,
#     'nh3': 2.12},
#    'dt': 1731528000},
#   {'main': {'aqi': 1},
#    'components': {'co': 377.18,
#     'no': 0.01,
#     'no2': 8.31,
#     'o3': 16.63,
#     'so2': 2.21,
#     'pm2_5': 4.45,
#     'pm10': 6.05,
#     'nh3': 1.99},
#    'dt': 1731531600},
#   {'main': {'aqi': 1},
#    'components': {'co': 370.5,
#     'no': 0.01,
#     'no2': 7.63,
#     'o3': 16.63,
#     'so2': 2.32,
#     'pm2_5': 4.1,
#     'pm10': 5.43,
#     'nh3': 1.84},
#    'dt': 1731535200},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.02,
#     'no2': 7.37,
#     'o3': 16.09,
#     'so2': 2.41,
#     'pm2_5': 4.15,
#     'pm10': 5.33,
#     'nh3': 1.76},
#    'dt': 1731538800},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 0.03,
#     'no2': 7.54,
#     'o3': 15.2,
#     'so2': 2.5,
#     'pm2_5': 4.38,
#     'pm10': 5.52,
#     'nh3': 1.74},
#    'dt': 1731542400},
#   {'main': {'aqi': 1},
#    'components': {'co': 397.21,
#     'no': 0.12,
#     'no2': 8.57,
#     'o3': 13.23,
#     'so2': 2.56,
#     'pm2_5': 4.85,
#     'pm10': 6.35,
#     'nh3': 1.9},
#    'dt': 1731546000},
#   {'main': {'aqi': 1},
#    'components': {'co': 433.92,
#     'no': 0.92,
#     'no2': 10.45,
#     'o3': 11.09,
#     'so2': 2.92,
#     'pm2_5': 5.38,
#     'pm10': 7.77,
#     'nh3': 2.06},
#    'dt': 1731549600},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 3.3,
#     'no2': 9.6,
#     'o3': 13.95,
#     'so2': 3.31,
#     'pm2_5': 5.42,
#     'pm10': 8.37,
#     'nh3': 2.12},
#    'dt': 1731553200},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 2.93,
#     'no2': 8.4,
#     'o3': 20.21,
#     'so2': 3.19,
#     'pm2_5': 4.54,
#     'pm10': 7.19,
#     'nh3': 1.87},
#    'dt': 1731556800},
#   {'main': {'aqi': 1},
#    'components': {'co': 393.87,
#     'no': 1.61,
#     'no2': 7.71,
#     'o3': 24.32,
#     'so2': 3.07,
#     'pm2_5': 3.91,
#     'pm10': 6.04,
#     'nh3': 1.84},
#    'dt': 1731560400},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.57,
#     'no2': 7.54,
#     'o3': 25.75,
#     'so2': 3.07,
#     'pm2_5': 3.48,
#     'pm10': 5.14,
#     'nh3': 1.84},
#    'dt': 1731564000},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.16,
#     'no': 0.08,
#     'no2': 7.03,
#     'o3': 27.89,
#     'so2': 2.95,
#     'pm2_5': 2.86,
#     'pm10': 4.07,
#     'nh3': 1.58},
#    'dt': 1731567600},
#   {'main': {'aqi': 1},
#    'components': {'co': 383.85,
#     'no': 0.14,
#     'no2': 7.03,
#     'o3': 30.04,
#     'so2': 2.65,
#     'pm2_5': 2.58,
#     'pm10': 3.69,
#     'nh3': 1.52},
#    'dt': 1731571200},
#   {'main': {'aqi': 1},
#    'components': {'co': 400.54,
#     'no': 0.24,
#     'no2': 7.63,
#     'o3': 29.68,
#     'so2': 2.38,
#     'pm2_5': 2.57,
#     'pm10': 3.73,
#     'nh3': 1.57},
#    'dt': 1731574800},
#   {'main': {'aqi': 1},
#    'components': {'co': 410.56,
#     'no': 0.28,
#     'no2': 8.74,
#     'o3': 27.89,
#     'so2': 2.41,
#     'pm2_5': 2.74,
#     'pm10': 3.99,
#     'nh3': 1.69},
#    'dt': 1731578400},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 0.18,
#     'no2': 11.48,
#     'o3': 23.96,
#     'so2': 2.8,
#     'pm2_5': 3.52,
#     'pm10': 4.96,
#     'nh3': 1.95},
#    'dt': 1731582000},
#   {'main': {'aqi': 1},
#    'components': {'co': 447.27,
#     'no': 0.07,
#     'no2': 14.22,
#     'o3': 22.71,
#     'so2': 3.16,
#     'pm2_5': 4.3,
#     'pm10': 5.89,
#     'nh3': 2.06},
#    'dt': 1731585600},
#   {'main': {'aqi': 1},
#    'components': {'co': 460.62,
#     'no': 0.02,
#     'no2': 14.74,
#     'o3': 24.68,
#     'so2': 3.16,
#     'pm2_5': 4.93,
#     'pm10': 6.72,
#     'nh3': 2.06},
#    'dt': 1731589200},
#   {'main': {'aqi': 1},
#    'components': {'co': 460.62,
#     'no': 0.01,
#     'no2': 13.37,
#     'o3': 28.25,
#     'so2': 2.89,
#     'pm2_5': 5.5,
#     'pm10': 7.54,
#     'nh3': 1.92},
#    'dt': 1731592800},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.01,
#     'no2': 12.17,
#     'o3': 30.4,
#     'so2': 2.8,
#     'pm2_5': 6.05,
#     'pm10': 8.12,
#     'nh3': 1.74},
#    'dt': 1731596400},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.01,
#     'no2': 12.34,
#     'o3': 29.33,
#     'so2': 2.71,
#     'pm2_5': 6.85,
#     'pm10': 9.3,
#     'nh3': 1.93},
#    'dt': 1731600000},
#   {'main': {'aqi': 1},
#    'components': {'co': 467.3,
#     'no': 0.02,
#     'no2': 13.71,
#     'o3': 24.68,
#     'so2': 2.8,
#     'pm2_5': 7.98,
#     'pm10': 10.92,
#     'nh3': 2.31},
#    'dt': 1731603600},
#   {'main': {'aqi': 1},
#    'components': {'co': 480.65,
#     'no': 0.03,
#     'no2': 15.08,
#     'o3': 19.67,
#     'so2': 2.74,
#     'pm2_5': 8.82,
#     'pm10': 11.71,
#     'nh3': 2.47},
#    'dt': 1731607200},
#   {'main': {'aqi': 1},
#    'components': {'co': 487.33,
#     'no': 0.04,
#     'no2': 15.42,
#     'o3': 15.74,
#     'so2': 2.68,
#     'pm2_5': 9.31,
#     'pm10': 11.81,
#     'nh3': 2.5},
#    'dt': 1731610800},
#   {'main': {'aqi': 1},
#    'components': {'co': 494,
#     'no': 0.04,
#     'no2': 14.74,
#     'o3': 13.59,
#     'so2': 2.77,
#     'pm2_5': 9.56,
#     'pm10': 11.86,
#     'nh3': 2.47},
#    'dt': 1731614400},
#   {'main': {'aqi': 1},
#    'components': {'co': 487.33,
#     'no': 0.03,
#     'no2': 13.19,
#     'o3': 13.59,
#     'so2': 2.86,
#     'pm2_5': 9.14,
#     'pm10': 11.3,
#     'nh3': 2.41},
#    'dt': 1731618000},
#   {'main': {'aqi': 1},
#    'components': {'co': 473.98,
#     'no': 0.02,
#     'no2': 11.14,
#     'o3': 15.56,
#     'so2': 2.86,
#     'pm2_5': 8.19,
#     'pm10': 10,
#     'nh3': 2.18},
#    'dt': 1731621600},
#   {'main': {'aqi': 1},
#    'components': {'co': 460.62,
#     'no': 0.01,
#     'no2': 9.34,
#     'o3': 18.42,
#     'so2': 2.74,
#     'pm2_5': 7.14,
#     'pm10': 8.58,
#     'nh3': 1.92},
#    'dt': 1731625200},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.01,
#     'no2': 8.23,
#     'o3': 20.92,
#     'so2': 2.77,
#     'pm2_5': 6.27,
#     'pm10': 7.46,
#     'nh3': 1.73},
#    'dt': 1731628800},
#   {'main': {'aqi': 1},
#    'components': {'co': 440.6,
#     'no': 0.02,
#     'no2': 8.23,
#     'o3': 22.71,
#     'so2': 2.83,
#     'pm2_5': 5.73,
#     'pm10': 7.05,
#     'nh3': 1.65},
#    'dt': 1731632400},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.15,
#     'no2': 10.45,
#     'o3': 20.92,
#     'so2': 3.25,
#     'pm2_5': 6.22,
#     'pm10': 8.14,
#     'nh3': 1.73},
#    'dt': 1731636000},
#   {'main': {'aqi': 1},
#    'components': {'co': 467.3,
#     'no': 0.82,
#     'no2': 11.48,
#     'o3': 21.1,
#     'so2': 3.76,
#     'pm2_5': 6.15,
#     'pm10': 8.33,
#     'nh3': 1.76},
#    'dt': 1731639600},
#   {'main': {'aqi': 1},
#    'components': {'co': 453.95,
#     'no': 0.99,
#     'no2': 10.02,
#     'o3': 25.39,
#     'so2': 3.87,
#     'pm2_5': 5.3,
#     'pm10': 7.31,
#     'nh3': 1.69},
#    'dt': 1731643200},
#   {'main': {'aqi': 1},
#    'components': {'co': 433.92,
#     'no': 1.12,
#     'no2': 8.23,
#     'o3': 29.33,
#     'so2': 3.67,
#     'pm2_5': 4.64,
#     'pm10': 6.48,
#     'nh3': 1.79},
#    'dt': 1731646800},
#   {'main': {'aqi': 1},
#    'components': {'co': 413.89,
#     'no': 1.06,
#     'no2': 6.43,
#     'o3': 33.97,
#     'so2': 3.25,
#     'pm2_5': 3.89,
#     'pm10': 5.42,
#     'nh3': 1.82},
#    'dt': 1731650400},
#   {'main': {'aqi': 1},
#    'components': {'co': 410.56,
#     'no': 1.03,
#     'no2': 6.34,
#     'o3': 37.55,
#     'so2': 3.07,
#     'pm2_5': 3.52,
#     'pm10': 4.97,
#     'nh3': 1.99},
#    'dt': 1731654000},
#   {'main': {'aqi': 1},
#    'components': {'co': 420.57,
#     'no': 1.16,
#     'no2': 7.45,
#     'o3': 37.19,
#     'so2': 2.8,
#     'pm2_5': 3.25,
#     'pm10': 4.85,
#     'nh3': 2.22},
#    'dt': 1731657600},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 1.33,
#     'no2': 8.4,
#     'o3': 35.41,
#     'so2': 2.56,
#     'pm2_5': 2.99,
#     'pm10': 4.71,
#     'nh3': 2.37},
#    'dt': 1731661200},
#   {'main': {'aqi': 1},
#    'components': {'co': 433.92,
#     'no': 1.41,
#     'no2': 9.6,
#     'o3': 34.33,
#     'so2': 2.77,
#     'pm2_5': 3.06,
#     'pm10': 4.84,
#     'nh3': 2.47},
#    'dt': 1731664800},
#   {'main': {'aqi': 1},
#    'components': {'co': 447.27,
#     'no': 1.08,
#     'no2': 12.51,
#     'o3': 31.83,
#     'so2': 3.28,
#     'pm2_5': 3.65,
#     'pm10': 5.5,
#     'nh3': 2.47},
#    'dt': 1731668400},
#   {'main': {'aqi': 1},
#    'components': {'co': 467.3,
#     'no': 0.34,
#     'no2': 15.77,
#     'o3': 28.97,
#     'so2': 3.67,
#     'pm2_5': 4.24,
#     'pm10': 6.08,
#     'nh3': 2.25},
#    'dt': 1731672000},
#   {'main': {'aqi': 1},
#    'components': {'co': 487.33,
#     'no': 0.03,
#     'no2': 17.82,
#     'o3': 26.82,
#     'so2': 3.64,
#     'pm2_5': 5.04,
#     'pm10': 7.23,
#     'nh3': 2.18},
#    'dt': 1731675600},
#   {'main': {'aqi': 1},
#    'components': {'co': 514.03,
#     'no': 0.04,
#     'no2': 19.54,
#     'o3': 23.25,
#     'so2': 3.61,
#     'pm2_5': 6.55,
#     'pm10': 9.61,
#     'nh3': 2.37},
#    'dt': 1731679200},
#   {'main': {'aqi': 1},
#    'components': {'co': 527.38,
#     'no': 0.04,
#     'no2': 18.85,
#     'o3': 22.53,
#     'so2': 3.46,
#     'pm2_5': 7.62,
#     'pm10': 11.17,
#     'nh3': 2.44},
#    'dt': 1731682800},
#   {'main': {'aqi': 1},
#    'components': {'co': 520.71,
#     'no': 0.03,
#     'no2': 16.28,
#     'o3': 23.96,
#     'so2': 3.04,
#     'pm2_5': 8.08,
#     'pm10': 11.51,
#     'nh3': 2.47},
#    'dt': 1731686400},
#   {'main': {'aqi': 1},
#    'components': {'co': 514.03,
#     'no': 0.02,
#     'no2': 14.39,
#     'o3': 23.6,
#     'so2': 2.77,
#     'pm2_5': 8.5,
#     'pm10': 11.73,
#     'nh3': 2.47},
#    'dt': 1731690000},
#   {'main': {'aqi': 1},
#    'components': {'co': 514.03,
#     'no': 0.03,
#     'no2': 14.05,
#     'o3': 21.28,
#     'so2': 2.56,
#     'pm2_5': 8.87,
#     'pm10': 11.58,
#     'nh3': 2.34},
#    'dt': 1731693600},
#   {'main': {'aqi': 1},
#    'components': {'co': 514.03,
#     'no': 0.03,
#     'no2': 14.05,
#     'o3': 18.42,
#     'so2': 2.44,
#     'pm2_5': 9.18,
#     'pm10': 11.31,
#     'nh3': 2.31},
#    'dt': 1731697200},
#   {'main': {'aqi': 2},
#    'components': {'co': 514.03,
#     'no': 0.02,
#     'no2': 13.54,
#     'o3': 15.91,
#     'so2': 2.41,
#     'pm2_5': 10.26,
#     'pm10': 12.21,
#     'nh3': 2.44},
#    'dt': 1731700800},
#   {'main': {'aqi': 2},
#    'components': {'co': 527.38,
#     'no': 0.02,
#     'no2': 13.71,
#     'o3': 13.41,
#     'so2': 2.56,
#     'pm2_5': 11.87,
#     'pm10': 13.85,
#     'nh3': 2.6},
#    'dt': 1731704400},
#   {'main': {'aqi': 2},
#    'components': {'co': 534.06,
#     'no': 0.03,
#     'no2': 14.39,
#     'o3': 11.44,
#     'so2': 2.71,
#     'pm2_5': 12.62,
#     'pm10': 14.55,
#     'nh3': 2.56},
#    'dt': 1731708000},
#   {'main': {'aqi': 2},
#    'components': {'co': 540.73,
#     'no': 0.04,
#     'no2': 14.74,
#     'o3': 10.46,
#     'so2': 2.62,
#     'pm2_5': 11.89,
#     'pm10': 13.55,
#     'nh3': 2.41},
#    'dt': 1731711600},
#   {'main': {'aqi': 2},
#    'components': {'co': 534.06,
#     'no': 0.05,
#     'no2': 14.05,
#     'o3': 10.91,
#     'so2': 2.53,
#     'pm2_5': 10.49,
#     'pm10': 11.91,
#     'nh3': 2.15},
#    'dt': 1731715200},
#   {'main': {'aqi': 1},
#    'components': {'co': 507.35,
#     'no': 0.08,
#     'no2': 12.34,
#     'o3': 12.7,
#     'so2': 2.41,
#     'pm2_5': 8.39,
#     'pm10': 9.72,
#     'nh3': 1.8},
#    'dt': 1731718800},
#   {'main': {'aqi': 1},
#    'components': {'co': 507.35,
#     'no': 0.47,
#     'no2': 12.34,
#     'o3': 11.44,
#     'so2': 2.56,
#     'pm2_5': 8.02,
#     'pm10': 9.76,
#     'nh3': 1.82},
#    'dt': 1731722400},
#   {'main': {'aqi': 1},
#    'components': {'co': 507.35,
#     'no': 1.42,
#     'no2': 12,
#     'o3': 11,
#     'so2': 2.8,
#     'pm2_5': 7.7,
#     'pm10': 9.66,
#     'nh3': 1.82},
#    'dt': 1731726000},
#   {'main': {'aqi': 1},
#    'components': {'co': 473.98,
#     'no': 1.45,
#     'no2': 10.45,
#     'o3': 13.23,
#     'so2': 3.01,
#     'pm2_5': 6.38,
#     'pm10': 8.17,
#     'nh3': 1.76},
#    'dt': 1731729600},
#   {'main': {'aqi': 1},
#    'components': {'co': 433.92,
#     'no': 1.24,
#     'no2': 8.05,
#     'o3': 18.42,
#     'so2': 3.16,
#     'pm2_5': 5.04,
#     'pm10': 6.59,
#     'nh3': 1.77},
#    'dt': 1731733200},
#   {'main': {'aqi': 1},
#    'components': {'co': 393.87,
#     'no': 0.89,
#     'no2': 6.34,
#     'o3': 26.82,
#     'so2': 3.19,
#     'pm2_5': 4.24,
#     'pm10': 5.54,
#     'nh3': 1.77},
#    'dt': 1731736800},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.61,
#     'no2': 5.57,
#     'o3': 36.48,
#     'so2': 2.8,
#     'pm2_5': 3.93,
#     'pm10': 5.11,
#     'nh3': 1.82},
#    'dt': 1731740400},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.71,
#     'no2': 5.74,
#     'o3': 42.2,
#     'so2': 2.24,
#     'pm2_5': 3.96,
#     'pm10': 5.26,
#     'nh3': 2.01},
#    'dt': 1731744000},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 0.89,
#     'no2': 6.08,
#     'o3': 45.78,
#     'so2': 1.97,
#     'pm2_5': 4.45,
#     'pm10': 5.91,
#     'nh3': 2.28},
#    'dt': 1731747600},
#   {'main': {'aqi': 1},
#    'components': {'co': 393.87,
#     'no': 0.89,
#     'no2': 7.2,
#     'o3': 45.42,
#     'so2': 2,
#     'pm2_5': 4.87,
#     'pm10': 6.43,
#     'nh3': 2.47},
#    'dt': 1731751200},
#   {'main': {'aqi': 1},
#    'components': {'co': 410.56,
#     'no': 0.59,
#     'no2': 9.42,
#     'o3': 40.05,
#     'so2': 2.09,
#     'pm2_5': 5,
#     'pm10': 6.61,
#     'nh3': 2.41},
#    'dt': 1731754800},
#   {'main': {'aqi': 1},
#    'components': {'co': 433.92,
#     'no': 0.17,
#     'no2': 12.51,
#     'o3': 33.62,
#     'so2': 2.21,
#     'pm2_5': 5.09,
#     'pm10': 6.8,
#     'nh3': 2.31},
#    'dt': 1731758400},
#   {'main': {'aqi': 1},
#    'components': {'co': 440.6,
#     'no': 0.01,
#     'no2': 13.02,
#     'o3': 30.76,
#     'so2': 2.15,
#     'pm2_5': 5.13,
#     'pm10': 7.05,
#     'nh3': 2.28},
#    'dt': 1731762000},
#   {'main': {'aqi': 1},
#    'components': {'co': 440.6,
#     'no': 0.01,
#     'no2': 12.85,
#     'o3': 28.25,
#     'so2': 2.35,
#     'pm2_5': 5.38,
#     'pm10': 7.74,
#     'nh3': 2.34},
#    'dt': 1731765600},
#   {'main': {'aqi': 1},
#    'components': {'co': 440.6,
#     'no': 0.01,
#     'no2': 12.34,
#     'o3': 26.46,
#     'so2': 2.47,
#     'pm2_5': 5.46,
#     'pm10': 7.94,
#     'nh3': 2.22},
#    'dt': 1731769200},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 0.01,
#     'no2': 10.28,
#     'o3': 26.46,
#     'so2': 2.29,
#     'pm2_5': 5.04,
#     'pm10': 7.58,
#     'nh3': 2.09},
#    'dt': 1731772800},
#   {'main': {'aqi': 1},
#    'components': {'co': 420.57,
#     'no': 0.01,
#     'no2': 8.83,
#     'o3': 25.03,
#     'so2': 2.18,
#     'pm2_5': 4.85,
#     'pm10': 7.5,
#     'nh3': 2.15},
#    'dt': 1731776400},
#   {'main': {'aqi': 1},
#    'components': {'co': 417.23,
#     'no': 0.01,
#     'no2': 8.31,
#     'o3': 22.71,
#     'so2': 2.09,
#     'pm2_5': 4.82,
#     'pm10': 7.06,
#     'nh3': 2.15},
#    'dt': 1731780000},
#   {'main': {'aqi': 1},
#    'components': {'co': 407.22,
#     'no': 0.01,
#     'no2': 7.71,
#     'o3': 21.1,
#     'so2': 2.06,
#     'pm2_5': 4.72,
#     'pm10': 6.48,
#     'nh3': 2.06},
#    'dt': 1731783600},
#   {'main': {'aqi': 1},
#    'components': {'co': 393.87,
#     'no': 0.01,
#     'no2': 6.68,
#     'o3': 20.56,
#     'so2': 1.97,
#     'pm2_5': 4.53,
#     'pm10': 6.04,
#     'nh3': 1.98},
#    'dt': 1731787200},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 0,
#     'no2': 5.91,
#     'o3': 20.56,
#     'so2': 1.77,
#     'pm2_5': 4.11,
#     'pm10': 5.41,
#     'nh3': 1.84},
#    'dt': 1731790800},
#   {'main': {'aqi': 1},
#    'components': {'co': 370.5,
#     'no': 0,
#     'no2': 5.4,
#     'o3': 21.46,
#     'so2': 1.62,
#     'pm2_5': 3.46,
#     'pm10': 4.36,
#     'nh3': 1.5},
#    'dt': 1731794400},
#   {'main': {'aqi': 1},
#    'components': {'co': 363.83,
#     'no': 0,
#     'no2': 5.01,
#     'o3': 22.71,
#     'so2': 1.56,
#     'pm2_5': 3.04,
#     'pm10': 3.66,
#     'nh3': 1.27},
#    'dt': 1731798000},
#   {'main': {'aqi': 1},
#    'components': {'co': 360.49,
#     'no': 0,
#     'no2': 4.63,
#     'o3': 25.75,
#     'so2': 1.56,
#     'pm2_5': 2.75,
#     'pm10': 3.26,
#     'nh3': 1.19},
#    'dt': 1731801600},
#   {'main': {'aqi': 1},
#    'components': {'co': 363.83,
#     'no': 0,
#     'no2': 4.37,
#     'o3': 33.26,
#     'so2': 1.51,
#     'pm2_5': 2.51,
#     'pm10': 3.15,
#     'nh3': 1.19},
#    'dt': 1731805200},
#   {'main': {'aqi': 1},
#    'components': {'co': 387.19,
#     'no': 0.03,
#     'no2': 5.48,
#     'o3': 38.62,
#     'so2': 1.8,
#     'pm2_5': 2.63,
#     'pm10': 3.69,
#     'nh3': 1.35},
#    'dt': 1731808800},
#   {'main': {'aqi': 1},
#    'components': {'co': 410.56,
#     'no': 0.3,
#     'no2': 6.68,
#     'o3': 41.49,
#     'so2': 2.21,
#     'pm2_5': 2.9,
#     'pm10': 4.25,
#     'nh3': 1.52},
#    'dt': 1731812400},
#   {'main': {'aqi': 1},
#    'components': {'co': 413.9,
#     'no': 0.29,
#     'no2': 6.51,
#     'o3': 44.35,
#     'so2': 2.44,
#     'pm2_5': 2.97,
#     'pm10': 4.34,
#     'nh3': 1.65},
#    'dt': 1731816000},
#   {'main': {'aqi': 1},
#    'components': {'co': 410.56,
#     'no': 0.39,
#     'no2': 5.14,
#     'o3': 47.92,
#     'so2': 2.33,
#     'pm2_5': 2.96,
#     'pm10': 4.19,
#     'nh3': 1.71},
#    'dt': 1731819600},
#   {'main': {'aqi': 1},
#    'components': {'co': 403.88,
#     'no': 0.36,
#     'no2': 3.68,
#     'o3': 55.08,
#     'so2': 2.12,
#     'pm2_5': 3,
#     'pm10': 3.99,
#     'nh3': 1.62},
#    'dt': 1731823200},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.24,
#     'no2': 2.68,
#     'o3': 61.51,
#     'so2': 1.8,
#     'pm2_5': 2.54,
#     'pm10': 3.23,
#     'nh3': 1.28},
#    'dt': 1731826800},
#   {'main': {'aqi': 2},
#    'components': {'co': 380.52,
#     'no': 0.16,
#     'no2': 2.66,
#     'o3': 62.94,
#     'so2': 1.68,
#     'pm2_5': 2.5,
#     'pm10': 3.1,
#     'nh3': 1.2},
#    'dt': 1731830400},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.1,
#     'no2': 3,
#     'o3': 63.66,
#     'so2': 1.73,
#     'pm2_5': 2.93,
#     'pm10': 3.54,
#     'nh3': 1.28},
#    'dt': 1731834000},
#   {'main': {'aqi': 1},
#    'components': {'co': 427.25,
#     'no': 0.31,
#     'no2': 6.26,
#     'o3': 58.65,
#     'so2': 2.09,
#     'pm2_5': 4.47,
#     'pm10': 5.66,
#     'nh3': 2.31},
#    'dt': 1731837600},
#   {'main': {'aqi': 1},
#    'components': {'co': 500.68,
#     'no': 0.75,
#     'no2': 12.34,
#     'o3': 47.92,
#     'so2': 2.56,
#     'pm2_5': 6.75,
#     'pm10': 8.96,
#     'nh3': 3.42},
#    'dt': 1731841200},
#   {'main': {'aqi': 1},
#    'components': {'co': 594.14,
#     'no': 0.69,
#     'no2': 20.39,
#     'o3': 37.91,
#     'so2': 3.19,
#     'pm2_5': 9.29,
#     'pm10': 12.46,
#     'nh3': 3.99},
#    'dt': 1731844800},
#   {'main': {'aqi': 2},
#    'components': {'co': 667.57,
#     'no': 0.04,
#     'no2': 25.71,
#     'o3': 30.76,
#     'so2': 3.73,
#     'pm2_5': 11.8,
#     'pm10': 16.32,
#     'nh3': 4.69},
#    'dt': 1731848400},
#   {'main': {'aqi': 2},
#    'components': {'co': 707.63,
#     'no': 0.02,
#     'no2': 25.36,
#     'o3': 27.9,
#     'so2': 4.11,
#     'pm2_5': 14.46,
#     'pm10': 20.62,
#     'nh3': 5},
#    'dt': 1731852000},
#   {'main': {'aqi': 2},
#    'components': {'co': 741.01,
#     'no': 0.02,
#     'no2': 23.99,
#     'o3': 25.75,
#     'so2': 4.41,
#     'pm2_5': 17.41,
#     'pm10': 25.04,
#     'nh3': 4.94},
#    'dt': 1731855600},
#   {'main': {'aqi': 2},
#    'components': {'co': 734.33,
#     'no': 0.02,
#     'no2': 20.74,
#     'o3': 24.32,
#     'so2': 4.17,
#     'pm2_5': 19.61,
#     'pm10': 28.06,
#     'nh3': 4.43},
#    'dt': 1731859200},
#   {'main': {'aqi': 2},
#    'components': {'co': 680.92,
#     'no': 0.01,
#     'no2': 16.79,
#     'o3': 25.39,
#     'so2': 3.49,
#     'pm2_5': 19.79,
#     'pm10': 28.26,
#     'nh3': 3.8},
#    'dt': 1731862800},
#   {'main': {'aqi': 2},
#    'components': {'co': 607.49,
#     'no': 0.01,
#     'no2': 13.02,
#     'o3': 28.97,
#     'so2': 2.68,
#     'pm2_5': 18.59,
#     'pm10': 25.71,
#     'nh3': 3.17},
#    'dt': 1731866400},
#   {'main': {'aqi': 2},
#    'components': {'co': 534.06,
#     'no': 0,
#     'no2': 9.25,
#     'o3': 35.41,
#     'so2': 2.15,
#     'pm2_5': 18.84,
#     'pm10': 23.95,
#     'nh3': 2.66},
#    'dt': 1731870000},
#   {'main': {'aqi': 2},
#    'components': {'co': 500.68,
#     'no': 0,
#     'no2': 7.2,
#     'o3': 38.27,
#     'so2': 2.06,
#     'pm2_5': 24.52,
#     'pm10': 29.06,
#     'nh3': 2.5},
#    'dt': 1731873600},
#   {'main': {'aqi': 3},
#    'components': {'co': 487.33,
#     'no': 0,
#     'no2': 6.08,
#     'o3': 40.77,
#     'so2': 2.09,
#     'pm2_5': 36.79,
#     'pm10': 41.62,
#     'nh3': 2.34},
#    'dt': 1731877200},
#   {'main': {'aqi': 4},
#    'components': {'co': 494,
#     'no': 0,
#     'no2': 5.44,
#     'o3': 45.42,
#     'so2': 2.35,
#     'pm2_5': 50.46,
#     'pm10': 55.21,
#     'nh3': 2.06},
#    'dt': 1731880800},
#   {'main': {'aqi': 4},
#    'components': {'co': 500.68,
#     'no': 0,
#     'no2': 5.06,
#     'o3': 50.07,
#     'so2': 2.59,
#     'pm2_5': 54.18,
#     'pm10': 57.92,
#     'nh3': 1.77},
#    'dt': 1731884400},
#   {'main': {'aqi': 4},
#    'components': {'co': 500.68,
#     'no': 0,
#     'no2': 4.97,
#     'o3': 54.36,
#     'so2': 2.71,
#     'pm2_5': 51.66,
#     'pm10': 54.45,
#     'nh3': 1.65},
#    'dt': 1731888000},
#   {'main': {'aqi': 3},
#    'components': {'co': 514.03,
#     'no': 0,
#     'no2': 5.66,
#     'o3': 57.94,
#     'so2': 2.71,
#     'pm2_5': 47.42,
#     'pm10': 50.28,
#     'nh3': 1.77},
#    'dt': 1731891600},
#   {'main': {'aqi': 3},
#    'components': {'co': 534.06,
#     'no': 0.01,
#     'no2': 8.14,
#     'o3': 57.22,
#     'so2': 3.31,
#     'pm2_5': 47.66,
#     'pm10': 51.53,
#     'nh3': 1.98},
#    'dt': 1731895200},
#   {'main': {'aqi': 3},
#    'components': {'co': 560.76,
#     'no': 0.17,
#     'no2': 10.37,
#     'o3': 57.22,
#     'so2': 3.99,
#     'pm2_5': 44.59,
#     'pm10': 48.98,
#     'nh3': 2.06},
#    'dt': 1731898800},
#   {'main': {'aqi': 3},
#    'components': {'co': 547.41,
#     'no': 0.48,
#     'no2': 8.91,
#     'o3': 69.38,
#     'so2': 4.35,
#     'pm2_5': 35.97,
#     'pm10': 39.96,
#     'nh3': 1.84},
#    'dt': 1731902400},
#   {'main': {'aqi': 3},
#    'components': {'co': 520.71,
#     'no': 0.76,
#     'no2': 7.03,
#     'o3': 78.68,
#     'so2': 4.65,
#     'pm2_5': 29.18,
#     'pm10': 32.58,
#     'nh3': 1.96},
#    'dt': 1731906000},
#   {'main': {'aqi': 2},
#    'components': {'co': 500.68,
#     'no': 0.74,
#     'no2': 5.23,
#     'o3': 88.69,
#     'so2': 4.59,
#     'pm2_5': 23.02,
#     'pm10': 25.75,
#     'nh3': 2.03},
#    'dt': 1731909600},
#   {'main': {'aqi': 2},
#    'components': {'co': 427.25,
#     'no': 0.46,
#     'no2': 3.09,
#     'o3': 94.41,
#     'so2': 3.52,
#     'pm2_5': 14.54,
#     'pm10': 16.43,
#     'nh3': 1.58},
#    'dt': 1731913200},
#   {'main': {'aqi': 2},
#    'components': {'co': 390.53,
#     'no': 0.34,
#     'no2': 2.66,
#     'o3': 92.98,
#     'so2': 3.07,
#     'pm2_5': 12.67,
#     'pm10': 14.49,
#     'nh3': 1.44},
#    'dt': 1731916800},
#   {'main': {'aqi': 2},
#    'components': {'co': 377.18,
#     'no': 0.33,
#     'no2': 2.83,
#     'o3': 92.98,
#     'so2': 3.13,
#     'pm2_5': 14.86,
#     'pm10': 17.02,
#     'nh3': 1.5},
#    'dt': 1731920400},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 1.12,
#     'no2': 7.54,
#     'o3': 81.54,
#     'so2': 3.37,
#     'pm2_5': 19.34,
#     'pm10': 22.93,
#     'nh3': 2.95},
#    'dt': 1731924000},
#   {'main': {'aqi': 2},
#    'components': {'co': 560.76,
#     'no': 2.57,
#     'no2': 17.65,
#     'o3': 62.94,
#     'so2': 3.87,
#     'pm2_5': 24.82,
#     'pm10': 30.86,
#     'nh3': 5.45},
#    'dt': 1731927600},
#   {'main': {'aqi': 3},
#    'components': {'co': 720.98,
#     'no': 2.35,
#     'no2': 33.59,
#     'o3': 39.34,
#     'so2': 4.65,
#     'pm2_5': 29.48,
#     'pm10': 38.01,
#     'nh3': 7.92},
#    'dt': 1731931200},
#   {'main': {'aqi': 3},
#    'components': {'co': 827.79,
#     'no': 0.18,
#     'no2': 44.55,
#     'o3': 21.46,
#     'so2': 5.25,
#     'pm2_5': 33.5,
#     'pm10': 44.5,
#     'nh3': 9.88},
#    'dt': 1731934800},
#   {'main': {'aqi': 3},
#    'components': {'co': 854.49,
#     'no': 0.13,
#     'no2': 41.81,
#     'o3': 18.77,
#     'so2': 5.6,
#     'pm2_5': 37,
#     'pm10': 50.1,
#     'nh3': 10.13},
#    'dt': 1731938400},
#   {'main': {'aqi': 3},
#    'components': {'co': 847.82,
#     'no': 0.07,
#     'no2': 36.33,
#     'o3': 20.03,
#     'so2': 5.6,
#     'pm2_5': 40.49,
#     'pm10': 54.69,
#     'nh3': 8.74},
#    'dt': 1731942000},
#   {'main': {'aqi': 3},
#    'components': {'co': 787.74,
#     'no': 0.02,
#     'no2': 28.1,
#     'o3': 25.03,
#     'so2': 4.95,
#     'pm2_5': 43.46,
#     'pm10': 57.59,
#     'nh3': 6.9},
#    'dt': 1731945600},
#   {'main': {'aqi': 3},
#    'components': {'co': 714.3,
#     'no': 0,
#     'no2': 21.08,
#     'o3': 31.83,
#     'so2': 4.11,
#     'pm2_5': 47.45,
#     'pm10': 60.47,
#     'nh3': 5.32},
#    'dt': 1731949200},
#   {'main': {'aqi': 4},
#    'components': {'co': 634.19,
#     'no': 0,
#     'no2': 15.94,
#     'o3': 38.98,
#     'so2': 3.37,
#     'pm2_5': 53.97,
#     'pm10': 64.63,
#     'nh3': 4.18},
#    'dt': 1731952800},
#   {'main': {'aqi': 4},
#    'components': {'co': 567.44,
#     'no': 0,
#     'no2': 11.82,
#     'o3': 45.06,
#     'so2': 3.1,
#     'pm2_5': 63.49,
#     'pm10': 72.21,
#     'nh3': 3.36},
#    'dt': 1731956400},
#   {'main': {'aqi': 4},
#    'components': {'co': 540.73,
#     'no': 0,
#     'no2': 9.34,
#     'o3': 48.64,
#     'so2': 3.07,
#     'pm2_5': 72.2,
#     'pm10': 79.89,
#     'nh3': 2.72},
#    'dt': 1731960000},
#   {'main': {'aqi': 4},
#    'components': {'co': 520.71,
#     'no': 0,
#     'no2': 7.11,
#     'o3': 55.08,
#     'so2': 3.31,
#     'pm2_5': 73.56,
#     'pm10': 80.33,
#     'nh3': 2.34},
#    'dt': 1731963600},
#   {'main': {'aqi': 4},
#    'components': {'co': 507.36,
#     'no': 0,
#     'no2': 5.66,
#     'o3': 60.8,
#     'so2': 3.73,
#     'pm2_5': 64.26,
#     'pm10': 69.71,
#     'nh3': 2.09},
#    'dt': 1731967200},
#   {'main': {'aqi': 4},
#    'components': {'co': 500.68,
#     'no': 0,
#     'no2': 5.18,
#     'o3': 62.94,
#     'so2': 3.76,
#     'pm2_5': 52.38,
#     'pm10': 56.96,
#     'nh3': 2.06},
#    'dt': 1731970800},
#   {'main': {'aqi': 3},
#    'components': {'co': 500.68,
#     'no': 0,
#     'no2': 5.36,
#     'o3': 63.66,
#     'so2': 3.7,
#     'pm2_5': 42.8,
#     'pm10': 47.02,
#     'nh3': 2.12},
#    'dt': 1731974400},
#   {'main': {'aqi': 3},
#    'components': {'co': 514.03,
#     'no': 0,
#     'no2': 6.43,
#     'o3': 62.23,
#     'so2': 3.7,
#     'pm2_5': 37.29,
#     'pm10': 41.38,
#     'nh3': 2.15},
#    'dt': 1731978000},
#   {'main': {'aqi': 3},
#    'components': {'co': 554.09,
#     'no': 0.06,
#     'no2': 9.17,
#     'o3': 61.51,
#     'so2': 4.29,
#     'pm2_5': 35.75,
#     'pm10': 40.51,
#     'nh3': 2.22},
#    'dt': 1731981600},
#   {'main': {'aqi': 3},
#    'components': {'co': 574.11,
#     'no': 0.62,
#     'no2': 10.37,
#     'o3': 67.95,
#     'so2': 4.95,
#     'pm2_5': 36.62,
#     'pm10': 42.03,
#     'nh3': 2.15},
#    'dt': 1731985200},
#   {'main': {'aqi': 3},
#    'components': {'co': 554.09,
#     'no': 0.75,
#     'no2': 7.97,
#     'o3': 90.84,
#     'so2': 4.77,
#     'pm2_5': 34.65,
#     'pm10': 39.85,
#     'nh3': 1.82},
#    'dt': 1731988800},
#   {'main': {'aqi': 3},
#    'components': {'co': 534.06,
#     'no': 0.61,
#     'no2': 6.26,
#     'o3': 103,
#     'so2': 4.83,
#     'pm2_5': 36.37,
#     'pm10': 41.75,
#     'nh3': 2},
#    'dt': 1731992400},
#   {'main': {'aqi': 3},
#    'components': {'co': 520.71,
#     'no': 0.46,
#     'no2': 5.01,
#     'o3': 107.29,
#     'so2': 4.95,
#     'pm2_5': 37.98,
#     'pm10': 43.5,
#     'nh3': 2.15},
#    'dt': 1731996000},
#   {'main': {'aqi': 3},
#    'components': {'co': 480.65,
#     'no': 0.36,
#     'no2': 3.77,
#     'o3': 108.72,
#     'so2': 4.47,
#     'pm2_5': 33.05,
#     'pm10': 37.54,
#     'nh3': 1.71},
#    'dt': 1731999600},
#   {'main': {'aqi': 3},
#    'components': {'co': 460.63,
#     'no': 0.32,
#     'no2': 3.56,
#     'o3': 107.29,
#     'so2': 4.29,
#     'pm2_5': 30.76,
#     'pm10': 34.74,
#     'nh3': 1.57},
#    'dt': 1732003200},
#   {'main': {'aqi': 3},
#    'components': {'co': 453.95,
#     'no': 0.29,
#     'no2': 3.56,
#     'o3': 110.15,
#     'so2': 4.35,
#     'pm2_5': 32.11,
#     'pm10': 36.09,
#     'nh3': 1.63},
#    'dt': 1732006800},
#   {'main': {'aqi': 3},
#    'components': {'co': 473.98,
#     'no': 0.41,
#     'no2': 5.74,
#     'o3': 110.15,
#     'so2': 4.59,
#     'pm2_5': 35.52,
#     'pm10': 40.02,
#     'nh3': 2.31},
#    'dt': 1732010400},
#   {'main': {'aqi': 3},
#    'components': {'co': 534.06,
#     'no': 0.42,
#     'no2': 12,
#     'o3': 101.57,
#     'so2': 5.01,
#     'pm2_5': 40.07,
#     'pm10': 45.78,
#     'nh3': 3.74},
#    'dt': 1732014000},
#   {'main': {'aqi': 3},
#    'components': {'co': 607.49,
#     'no': 0.12,
#     'no2': 20.56,
#     'o3': 87.98,
#     'so2': 5.54,
#     'pm2_5': 44.07,
#     'pm10': 51.15,
#     'nh3': 5.19},
#    'dt': 1732017600},
#   {'main': {'aqi': 3},
#    'components': {'co': 680.92,
#     'no': 0,
#     'no2': 27.42,
#     'o3': 72.24,
#     'so2': 5.9,
#     'pm2_5': 49.28,
#     'pm10': 58.42,
#     'nh3': 6.71},
#    'dt': 1732021200},
#   {'main': {'aqi': 4},
#    'components': {'co': 747.68,
#     'no': 0,
#     'no2': 31.87,
#     'o3': 52.93,
#     'so2': 5.96,
#     'pm2_5': 57.61,
#     'pm10': 69.72,
#     'nh3': 8.11},
#    'dt': 1732024800},
#   {'main': {'aqi': 4},
#    'components': {'co': 794.41,
#     'no': 0,
#     'no2': 32.56,
#     'o3': 38.27,
#     'so2': 5.78,
#     'pm2_5': 67.48,
#     'pm10': 82.6,
#     'nh3': 8.74},
#    'dt': 1732028400},
#   {'main': {'aqi': 5},
#    'components': {'co': 787.74,
#     'no': 0,
#     'no2': 28.45,
#     'o3': 31.47,
#     'so2': 5.31,
#     'pm2_5': 76.55,
#     'pm10': 93.32,
#     'nh3': 8.11},
#    'dt': 1732032000},
#   {'main': {'aqi': 5},
#    'components': {'co': 734.33,
#     'no': 0,
#     'no2': 22.28,
#     'o3': 33.98,
#     'so2': 4.65,
#     'pm2_5': 83.43,
#     'pm10': 100.21,
#     'nh3': 7.03},
#    'dt': 1732035600},
#   {'main': {'aqi': 5},
#    'components': {'co': 680.92,
#     'no': 0,
#     'no2': 18.17,
#     'o3': 38.62,
#     'so2': 4.11,
#     'pm2_5': 87.94,
#     'pm10': 103.31,
#     'nh3': 5.7},
#    'dt': 1732039200},
#   {'main': {'aqi': 5},
#    'components': {'co': 640.87,
#     'no': 0,
#     'no2': 15.42,
#     'o3': 41.49,
#     'so2': 4.29,
#     'pm2_5': 90.63,
#     'pm10': 104.89,
#     'nh3': 4.75},
#    'dt': 1732042800},
#   {'main': {'aqi': 5},
#    'components': {'co': 607.49,
#     'no': 0,
#     'no2': 13.37,
#     'o3': 42.2,
#     'so2': 4.83,
#     'pm2_5': 90.81,
#     'pm10': 104.96,
#     'nh3': 4.18},
#    'dt': 1732046400},
#   {'main': {'aqi': 5},
#    'components': {'co': 560.76,
#     'no': 0,
#     'no2': 10.54,
#     'o3': 47.21,
#     'so2': 4.95,
#     'pm2_5': 87.86,
#     'pm10': 101.57,
#     'nh3': 3.42},
#    'dt': 1732050000},
#   {'main': {'aqi': 5},
#    'components': {'co': 527.38,
#     'no': 0,
#     'no2': 7.88,
#     'o3': 52.93,
#     'so2': 4.59,
#     'pm2_5': 85.77,
#     'pm10': 98.99,
#     'nh3': 2.66},
#    'dt': 1732053600},
#   {'main': {'aqi': 5},
#    'components': {'co': 514.03,
#     'no': 0,
#     'no2': 6.86,
#     'o3': 53.64,
#     'so2': 4.41,
#     'pm2_5': 86.78,
#     'pm10': 100.17,
#     'nh3': 2.28},
#    'dt': 1732057200},
#   {'main': {'aqi': 5},
#    'components': {'co': 520.71,
#     'no': 0,
#     'no2': 6.77,
#     'o3': 54.36,
#     'so2': 4.53,
#     'pm2_5': 90.76,
#     'pm10': 104.85,
#     'nh3': 2.15},
#    'dt': 1732060800},
#   {'main': {'aqi': 5},
#    'components': {'co': 534.06,
#     'no': 0,
#     'no2': 7.97,
#     'o3': 54.36,
#     'so2': 4.83,
#     'pm2_5': 96.86,
#     'pm10': 112.61,
#     'nh3': 2.22},
#    'dt': 1732064400},
#   {'main': {'aqi': 5},
#    'components': {'co': 567.44,
#     'no': 0.02,
#     'no2': 11.48,
#     'o3': 52.93,
#     'so2': 5.36,
#     'pm2_5': 103.92,
#     'pm10': 122.56,
#     'nh3': 2.41},
#    'dt': 1732068000},
#   {'main': {'aqi': 5},
#    'components': {'co': 594.14,
#     'no': 0.15,
#     'no2': 14.4,
#     'o3': 55.08,
#     'so2': 6.02,
#     'pm2_5': 109.94,
#     'pm10': 130.96,
#     'nh3': 2.6},
#    'dt': 1732071600},
#   {'main': {'aqi': 5},
#    'components': {'co': 540.73,
#     'no': 0.35,
#     'no2': 10.54,
#     'o3': 80.82,
#     'so2': 6.14,
#     'pm2_5': 110.21,
#     'pm10': 130.93,
#     'nh3': 1.85},
#    'dt': 1732075200},
#   {'main': {'aqi': 5},
#    'components': {'co': 514.03,
#     'no': 0.64,
#     'no2': 8.05,
#     'o3': 95.84,
#     'so2': 6.08,
#     'pm2_5': 101.02,
#     'pm10': 119.07,
#     'nh3': 1.69},
#    'dt': 1732078800}]}

# %% [markdown]
# # Step 3 PROCESS AND ANALYSE THE DATA

# %%
def process_aqi_data(data):
    records = []
    for item in data['list']:
        dt = datetime.datetime.fromtimestamp(item['dt'])
        aqi = item['main']['aqi']
        components = item['components']
        record = {
            'datetime': dt,
            'aqi' : aqi,
            **components
        }
        records.append(record)
    return pd.DataFrame(records)

aqi_df = process_aqi_data(aqi_data)

#plot AQI over time
plt.figure(figsize=(12,6))
plt.plot(aqi_df['datetime'], aqi_df['aqi'], marker='o', linestyle='-')
plt.title(f'Air Quality Index (AQI) in{city}')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.grid(True)
plt.show()

# %% [markdown]
# # PLot individual components

# %%
components = ['pm2_5' , 'pm10' , 'no2', 'so2' , 'o3' , 'co']
for component in components:
    plt.figure(figsize=(12,6))
    plt.plot(aqi_df['datetime'], aqi_df[component], marker='o', linestyle='-')
    plt.title(f'{component.upper()} Levels in {city}')
    plt.xlabel('Date')
    plt.ylabel(f'{component.upper()} (ug/m3)')
    plt.grid(True)
    plt.show()

# %% [markdown]
# # plotting multiple components in a single plot for comparison

# %%
plt.figure(figsize=(12,6))
for component in components:
    plt.plot(aqi_df['datetime'], aqi_df[component], marker='o',
             linestyle='-', label=component.upper())

plt.title(f'Pollutant Levels in {city}')
plt.xlabel('Date')
plt.ylabel('time')
plt.legend()
plt.show()

# %% [markdown]
# # scatter plot for AQI vs individual components

# %%
plt.figure(figsize=(12,6))
for component in components:
    plt.scatter(aqi_df[component], aqi_df['aqi'],  label=component.upper())

plt.title(f'Pollutant Levels in {city}')
plt.xlabel('Pollutant Level(ug/m3)')
plt.ylabel('AQI')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### To summarize, I have imported the required libraries like pandas(2.2.3), requests and datetime. Signed up open weather map website and downloaded the API key which is free version. Later, used the api key and city name, created a custom function and did the data analysis with retrieving the data like particle matter, & components (oxygen, carbon monoxide and others). Finally visulaized the data with respect to components and AQI in Mysuru, Karnataka region.
